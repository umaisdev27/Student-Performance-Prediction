# %%
import pandas as pd

from sklearn.model_selection import train_test_split

#Models
from sklearn.ensemble import RandomForestRegressor,AdaBoostRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.svm import SVR
from sklearn.model_selection import GridSearchCV

from sklearn.preprocessing import LabelEncoder,StandardScaler

from xgboost import XGBRegressor
from catboost import CatBoostRegressor

#Performance Metrics
from sklearn.metrics import r2_score

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("data/stud.csv")

# %%
LabelEncoder = LabelEncoder()
df['gender'] = LabelEncoder.fit_transform(df['gender'])
df['race_ethnicity'] = LabelEncoder.fit_transform(df['race_ethnicity'])
df['parental_level_of_education'] = LabelEncoder.fit_transform(df['parental_level_of_education'])
df['lunch'] = LabelEncoder.fit_transform(df['lunch'])
df['test_preparation_course'] = LabelEncoder.fit_transform(df['test_preparation_course'])

# %%
x = df.drop(['math_score'],axis=1)
y = df['math_score']

# %%
x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.33, random_state=42)

# %%
#feature Scaling
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
models = {
    'random_forest': RandomForestRegressor(),
    'Xg-Boost': XGBRegressor(),
    'Cat-Boost': CatBoostRegressor(),
    'Lasso': Lasso(),
    'Ridge': Ridge(),
    'svm': SVR(),
    'Decision-tree': DecisionTreeRegressor(),
    'KNeighborsRegressor': KNeighborsRegressor(),
    'Linear-Regressor': LinearRegression(),
    'AdaBoostRegressor': AdaBoostRegressor(),
}

# %% [markdown]
# # Decision tree

# %%
params = {
    'criterion' : ['poisson', 'absolute_error', 'squared_error', 'friedman_mse'],
    'splitter':['best', 'random'],
    'max_features':['sqrt','log2'],
    'min_samples_split':[2,3,4,5],
}

# %%
classifier = DecisionTreeRegressor()

# %%
cv = GridSearchCV(cassifier,paramas, cv=5, scoring='r2')

# %%
cv.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeRegressor(),
#              param_grid={'criterion': ['poisson', 'absolute_error',
#                                        'squared_error', 'friedman_mse'],
#                          'max_features': ['sqrt', 'log2'],
#                          'min_samples_split': [2, 3, 4, 5],
#                          'splitter': ['best', 'random']},
#              scoring='r2')

# %%
cv.best_params_
# Out:
# {'criterion': 'poisson',
#  'max_features': 'log2',
#  'min_samples_split': 5,
#  'splitter': 'random'}

# %%
y_pred = cv.predict(x_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.6807081083233599

# %% [markdown]
# # Random Forest

# %%
params_ran = {
    'n_estimators': [100, 200, 300],
    'max_depth': [None, 5, 10, 15],
    'min_samples_split': [2, 5, 10],
    'max_features': ['sqrt', 'log2'],
}

# %%
classi = RandomForestRegressor()

# %%
cv2 = GridSearchCV(classi,params_ran, cv=5, scoring='r2')

# %%
cv2.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_depth': [None, 5, 10, 15],
#                          'max_features': ['sqrt', 'log2'],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [100, 200, 300]},
#              scoring='r2')

# %%
/
# Out:
# {'max_depth': 15,
#  'max_features': 'log2',
#  'min_samples_split': 5,
#  'n_estimators': 300}

# %%
y_pred = cv2.predict(x_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.8416572519884409

# %% [markdown]
# # XG-Regressor

# %%
params_xgb = {
    'n_estimators': [100, 200, 300],
    'max_depth': [3, 5, 7],
    'learning_rate': [0.05, 0.1, 0.2],
    'subsample': [0.8, 1.0],
}

# %%
xg = XGBRegressor()

# %%
cv_xg = GridSearchCV(xg,params_xgb, cv=5, scoring='r2')

# %%
cv_xg.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=XGBRegressor(base_score=None, booster=None,
#                                     callbacks=None, colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None, device=None,
#                                     early_stopping_rounds=None,
#                                     enable_categorical=False, eval_metric=None,
#                                     feature_types=None, feature_weights=None,
#                                     gamma=None, grow_policy=None,
#                                     importance_type=None,
#                                     interaction_constraints=None...
#                                     max_cat_threshold=None,
#                                     max_cat_to_onehot=None, max_delta_step=None,
#                                     max_depth=None, max_leaves=None,
# ...

# %%
cv_xg.best_params_
# Out:
# {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.8}

# %%
y_pred = cv2.predict(x_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.8416572519884409

# %% [markdown]
# # cat_boost

# %%
params_catboost = {
    'iterations': [100, 200, 300],
    'learning_rate': [0.05, 0.1, 0.2],
    'depth': [4, 6, 8],
}
cat = CatBoostRegressor()

# %%
cv_cat = GridSearchCV(xg,params_catboost, cv=5, scoring='r2')

# %%
cv_cat.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=XGBRegressor(base_score=None, booster=None,
#                                     callbacks=None, colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None, device=None,
#                                     early_stopping_rounds=None,
#                                     enable_categorical=False, eval_metric=None,
#                                     feature_types=None, feature_weights=None,
#                                     gamma=None, grow_policy=None,
#                                     importance_type=None,
#                                     interaction_constraints=None,
#                                     learning_rate=None, max_bin=None,
#                                     max_cat_threshold=None,
#                                     max_cat_to_onehot=None, max_delta_step=None,
# ...

# %%
cv_cat.best_params_
# Out:
# {'depth': 4, 'iterations': 100, 'learning_rate': 0.05}

# %%
y_pred = cv_cat.predict(x_test)
r2_score(y_test,y_pred)
# Out:
# 0.8420991897583008

# %% [markdown]
# # Lasso

# %%
params_lasso = {
    'alpha': [0.001, 0.01, 0.1, 1.0, 10.0],
}
ls = Lasso()

# %%
cv_cat = GridSearchCV(ls,params_lasso, cv=5, scoring='r2')

# %%
cv_cat.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [0.001, 0.01, 0.1, 1.0, 10.0]}, scoring='r2')

# %%
cv_cat.best_params_
# Out:
# {'alpha': 0.01}

# %% [markdown]
# # Ridge

# %%
params_rid = {
    'alpha': [0.001, 0.01, 0.1, 1.0, 10.0],
}
rid = Ridge()

# %%
cv_rid = GridSearchCV(rid,params_rid, cv=5, scoring='r2')
cv_rid.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': [0.001, 0.01, 0.1, 1.0, 10.0]}, scoring='r2')

# %%
cv_rid.best_params_
# Out:
# {'alpha': 1.0}

# %% [markdown]
# # SVR

# %%
params_svr = {
    'C': [1, 10, 100],
    'kernel': ['rbf', 'linear'],
    'epsilon': [0.01, 0.1, 0.5],
}
svr = SVR()

# %%
cv_svr = GridSearchCV(svr,params_svr, cv=5, scoring='r2')
cv_svr.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=SVR(),
#              param_grid={'C': [1, 10, 100], 'epsilon': [0.01, 0.1, 0.5],
#                          'kernel': ['rbf', 'linear']},
#              scoring='r2')

# %%
cv_svr.best_params_
# Out:
# {'C': 1, 'epsilon': 0.5, 'kernel': 'linear'}

# %%
y_pred = cv_svr.predict(x_test)
r2_score(y_test,y_pred)
# Out:
# 0.8731376169754261

# %% [markdown]
# # KNN

# %%
params_knn = {
    'n_neighbors': [3, 5, 7, 9],
    'weights': ['uniform', 'distance'],
    'metric': ['minkowski', 'euclidean'],
}
knn = KNeighborsRegressor()

# %%
cv_knn = GridSearchCV(knn,params_knn, cv=5, scoring='r2')
cv_knn.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=KNeighborsRegressor(),
#              param_grid={'metric': ['minkowski', 'euclidean'],
#                          'n_neighbors': [3, 5, 7, 9],
#                          'weights': ['uniform', 'distance']},
#              scoring='r2')

# %%
cv_knn.best_params_
# Out:
# {'metric': 'minkowski', 'n_neighbors': 9, 'weights': 'distance'}

# %%
y_pred = cv_knn.predict(x_test)
r2_score(y_test,y_pred)
# Out:
# 0.7897801377456029

# %% [markdown]
# # Ada-Boost

# %%
params_adaboost = {
    'n_estimators': [100, 200, 300],
    'learning_rate': [0.01, 0.05, 0.1],
    'loss': ['linear', 'square'],
}
ada = AdaBoostRegressor()

# %%
cv_ada = GridSearchCV(ada,params_adaboost, cv=5, scoring='r2')
cv_ada.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=AdaBoostRegressor(),
#              param_grid={'learning_rate': [0.01, 0.05, 0.1],
#                          'loss': ['linear', 'square'],
#                          'n_estimators': [100, 200, 300]},
#              scoring='r2')

# %%
cv_ada.best_params_
# Out:
# {'learning_rate': 0.1, 'loss': 'square', 'n_estimators': 300}

# %%
y_pred = cv_ada.predict(x_test)
r2_score(y_test,y_pred)
# Out:
# 0.8316277968856973
